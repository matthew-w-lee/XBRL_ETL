# %%
#import client to connect with arelle web server
import arelle_client

#for dealing with file system
import os
from pathlib import Path

#load sample urls to sample SEC filings' xbrl instance
import pandas

#import lxml for parsing xml
import lxml
from lxml import etree
import html

#method was used to download xbrl data from arelle web server
#NOTE: XBRL DATA HAS ALREADY BEEN DOWNLOADED AND INCLUDED IN THIS REPOSITORY
# USING METHOD BELOW IS UNNCESSARY
def download_arelle_data(xbrl_path):

    #getting cik and accession number from xbrl path
    cik = xbrl_path.split("/")[6]
    accession_number =  xbrl_path.split("/")[7]
    
    #different types of xml files provided by arelle webserver
    arelle_data_sets = ["concepts", "pre", "dim", "facts", "factTable", "roleTypes"]
    
    #save xbrl files to folder
    filing_path = "arelle_xbrl/{0}/{1}/".format(cik, accession_number)
    for s in arelle_data_sets:
        full_path = filing_path + "{0}.xml".format(s)
        #download xbrl file to memory
        buffer = arelle_client.get_buffer(xbrl_path, s, "xml")
        if buffer:
            print("saving xml file to: {}".format(full_path))
            Path(filing_path).mkdir(parents=True, exist_ok=True)
            with open(full_path, mode="wb") as localfile:
                localfile.write(buffer)

# %%
#The following classes model the downloaded xml files and their directories to aid in pulling data

#path to stored xml files
ARELLE_DATA_PATH = "/home/jovyan/src/arelle_xbrl/"

#different type of xml files produced by arelle web server
ARELLE_DATA_SETS = {
    "dim": "dim.xml",
    "concepts": "concepts.xml",
    "facts": "facts.xml",
    "pre": "pre.xml",
    "roleTypes": "roleTypes.xml",
    "factTable": "factTable.xml"
}

#certain abstracts we're interested in; an abstract is a parent label used in XBRL that covers a set of child datapoints
#in this case, we're looking for the abstracts that represent the key financial statements
ABSTRACTS = {
    "balance_sheet": "us-gaap:StatementOfFinancialPositionAbstract",
    "income_statement": "us-gaap:IncomeStatementAbstract",
    "cash_flow_statement": "us-gaap:StatementOfCashFlowsAbstract",
}

#model of a single company and its data; has many filings
class CompanyData():
    
    def __init__(self, cik):
        self.cik = cik
        self.base_path = ARELLE_DATA_PATH + "{0}/".format(cik)
        self.accession_numbers = os.listdir(self.base_path)
        self.filings = [Filing(cik, f.path) for f in os.scandir(self.base_path) if f.is_dir()]
    
    def get_all(self, dataset):
        return [f.get_dataset(dataset) for f in self.filings]

#model of filing, which has several xml files
class Filing():
    
    def __init__(self, cik, path):
        self.cik = cik
        self.base_path = path
        self.filenames = os.listdir(self.base_path)
#        self.xml_files = self.process_xml_files()

    #this file provides the presentation structure on each financial statement/report presented in the filing
    def presentation_file(self):
        return PresentationFile(self.cik, self.base_path, "pre.xml")
    
    #this file provides the numeric data for each line item in a presentation
    def facts_file(self):
        return FactsFile(self.cik, self.base_path, "facts.xml")

    #this method finds the presentation in the filing that matches "abstract_name" and then merges
    #the numeric data via a LEFT JOIN; result is a DataFrame that contains all the relevant data
    #for the requested abstract_name in the filing
    def statement(self, abstract_name):
        accounts = self.presentation_file().accounts(abstract_name)
        facts = self.facts_file().data_df()
        final_statement = accounts.merge(facts, how="left", left_on="account", right_on="label")
        final_statement = final_statement.loc[:, ["account", "endInstant", "value"]]
        return final_statement
    
#model of a single xml file
class XMLFile():
    
    def __init__(self, cik, folder_path, filename):
        self.cik = cik
        self.folder_path = folder_path
        self.filename = filename
        self.full_file_path = folder_path + "/" + filename
    
    #parse xml content with lxml
    def get_xml(self):
        return etree.parse(self.full_file_path)

#model of xml file that contains XBRL presentation data
class PresentationFile(XMLFile):
    
    #pulls all xml nodes that match the requested abstract name
    def get_abstract(self, abstract):
        xml = self.get_xml()
        return xml.xpath("//concept[@label='{}']".format(abstract))

    #takes the first xml node returned by the get_abstract method above
    #then it finds all child nodes that does not have any child nodes itself
    #these nodes are actual line items in a report that have numeric data associated with them
    def line_items(self, abstract):
        final_items = []
        abstract_nodes = self.get_abstract(abstract)
        if abstract_nodes:
            a = abstract_nodes[0]
            line_items = a.xpath(".//concept[not(concept)]")
            for item in line_items:
                final_items.append(item.attrib['label'])
        return final_items

    #prepare the line items found above as a DataFrame for merging with facts
    def accounts(self, abstract):
        line_items = self.line_items(abstract)
        return pandas.DataFrame(line_items, columns=["account"])
            
class FactsFile(XMLFile):
    
    #selects all fact nodes, other than fact node with a child dimension
    #nodes with a dimension child relate to line items usually not contained in the main financial statements
    def items(self):
        return self.get_xml().xpath("//item[not(dimension)]")

    #prepare a DataFrame of facts for merging with the presentation line items
    def data_df(self):
        final_items = []
        items = self.items()
        for i in items:
            item_dict = {}
            item_dict['name'] = i.attrib['name']
            for child in i.getchildren():
                item_dict[child.tag] = child.text
            final_items.append(item_dict)
        return pandas.DataFrame(final_items)

# %%
#instantiate company data objects
companies = [CompanyData(c.name) for c in os.scandir(ARELLE_DATA_PATH)]

#list all companies by cik
for c in companies:
    print(c.cik)

#list all income_statements for particular company
for filing in companies[0].filings:
    display(filing.statement(ABSTRACTS["income_statement"]))
    

#list all balance_sheets for all companies
#for c in companies:
#    for f in c.filings:
#        df = f.statement(ABSTRACTS["balance_sheet"])
#        display(df)
# Out:
# 1463258
# 1704720
# 1512762
# 884269
# 910329
#                                                account  endInstant       value
# 0           us-gaap:OtherAlternativeEnergySalesRevenue  2013-12-31  1207618000
# 1           us-gaap:OtherAlternativeEnergySalesRevenue  2014-12-31  1052772000
# 2           us-gaap:OtherAlternativeEnergySalesRevenue  2015-12-31  1141281000
# 3                   regi:BiodieselGovernmentIncentives  2013-12-31   290393000
# 4                   regi:BiodieselGovernmentIncentives  2014-12-31   220634000
# 5                   regi:BiodieselGovernmentIncentives  2015-12-31   245868000
# 6                             us-gaap:OilAndGasRevenue  2013-12-31  1498011000
# 7                             us-gaap:OilAndGasRevenue  2014-12-31  1273406000
# 8                             us-gaap:OilAndGasRevenue  2015-12-31  1387149000
# 9                    us-gaap:SalesRevenueServicesGross  2013-12-31      127000
# 10                   us-gaap:SalesRevenueServicesGross  2014-12-31      425000
# 11                   us-gaap:SalesRevenueServicesGross  2015-12-31      195000
# 12                                    us-gaap:Revenues  2013-12-31  1498138000
# 13                                    us-gaap:Revenues  2014-03-31   219040000
# 14                                    us-gaap:Revenues  2014-06-30   332918000
# 15                                    us-gaap:Revenues  2014-09-30   384258000
# 16                                    us-gaap:Revenues  2014-12-31   337615000
# 17                                    us-gaap:Revenues  2014-12-31  1273831000
# 18                                    us-gaap:Revenues  2015-03-31   230918000
# 19                                    us-gaap:Revenues  2015-06-30   373762000
# 20                                    us-gaap:Revenues  2015-09-30   394856000
# 21                                    us-gaap:Revenues  2015-12-31   387808000
# 22                                    us-gaap:Revenues  2015-12-31  1387344000
# 23                             us-gaap:CostOfGoodsSold  2013-12-31  1209191000
# 24                             us-gaap:CostOfGoodsSold  2014-12-31  1070430000
# 25                             us-gaap:CostOfGoodsSold  2015-12-31  1272125000
# 26   us-gaap:RelatedPartyTransactionExpensesFromTra...  2013-12-31    49358000
# 27   us-gaap:RelatedPartyTransactionExpensesFromTra...  2014-12-31    42622000
# 28   us-gaap:RelatedPartyTransactionExpensesFromTra...  2015-12-31     4542000
# 29                              us-gaap:CostOfServices  2013-12-31      156000
# ..                                                 ...         ...         ...
# 126  us-gaap:NetIncomeLossAvailableToCommonStockhol...  2014-12-31    81620000
# 127  us-gaap:NetIncomeLossAvailableToCommonStockhol...  2015-12-31  -151392000
# 128                      us-gaap:EarningsPerShareBasic  2013-12-31        5.00
# 129                      us-gaap:EarningsPerShareBasic  2014-03-31       -0.05
# 130                      us-gaap:EarningsPerShareBasic  2014-06-30        0.27
# 131                      us-gaap:EarningsPerShareBasic  2014-09-30        0.11
# 132                      us-gaap:EarningsPerShareBasic  2014-12-31        1.61
# 133                      us-gaap:EarningsPerShareBasic  2014-12-31        2.00
# 134                      us-gaap:EarningsPerShareBasic  2015-03-31       -0.86
# 135                      us-gaap:EarningsPerShareBasic  2015-06-30       -0.05
# 136                      us-gaap:EarningsPerShareBasic  2015-09-30       -0.36
# 137                      us-gaap:EarningsPerShareBasic  2015-12-31       -2.18
# 138                      us-gaap:EarningsPerShareBasic  2015-12-31       -3.44
# 139                    us-gaap:EarningsPerShareDiluted  2013-12-31        5.00
# 140                    us-gaap:EarningsPerShareDiluted  2014-03-31       -0.06
# 141                    us-gaap:EarningsPerShareDiluted  2014-06-30        0.27
# 142                    us-gaap:EarningsPerShareDiluted  2014-09-30        0.11
# 143                    us-gaap:EarningsPerShareDiluted  2014-12-31        1.61
# 144                    us-gaap:EarningsPerShareDiluted  2014-12-31        1.99
# 145                    us-gaap:EarningsPerShareDiluted  2015-03-31       -0.86
# 146                    us-gaap:EarningsPerShareDiluted  2015-06-30       -0.05
# 147                    us-gaap:EarningsPerShareDiluted  2015-09-30       -0.36
# 148                    us-gaap:EarningsPerShareDiluted  2015-12-31       -2.18
# 149                    us-gaap:EarningsPerShareDiluted  2015-12-31       -3.44
# 150  us-gaap:WeightedAverageNumberOfSharesOutstandi...  2013-12-31    33045164
# 151  us-gaap:WeightedAverageNumberOfSharesOutstandi...  2014-12-31    40740411
# 152  us-gaap:WeightedAverageNumberOfSharesOutstandi...  2015-12-31    43958803
# 153  us-gaap:WeightedAverageNumberOfDilutedSharesOu...  2013-12-31    33052879
# 154  us-gaap:WeightedAverageNumberOfDilutedSharesOu...  2014-12-31    40749913
# 155  us-gaap:WeightedAverageNumberOfDilutedSharesOu...  2015-12-31    43958803
#
# [156 rows x 3 columns]
#                                                account  endInstant       value
# 0                      us-gaap:AlternativeEnergyMember         NaN         NaN
# 1            regi:RenewableIdentificationNumbersMember         NaN         NaN
# 2      regi:AlternativeEnergyGovermentIncentivesMember         NaN         NaN
# 3                 us-gaap:ProductAndServiceOtherMember         NaN         NaN
# 4    us-gaap:RevenueFromContractWithCustomerIncludi...  2018-12-31  2380701000
# 5    us-gaap:RevenueFromContractWithCustomerIncludi...  2017-12-31  2153537000
# 6    us-gaap:RevenueFromContractWithCustomerIncludi...  2016-12-31  2039067000
# 7                                     us-gaap:Revenues  2018-12-31  2382987000
# 8                                     us-gaap:Revenues  2017-12-31  2154655000
# 9                                     us-gaap:Revenues  2016-12-31  2039232000
# 10                                    us-gaap:Revenues  2018-12-31  2382987000
# 11                                    us-gaap:Revenues  2018-12-31  2382987000
# 12                                    us-gaap:Revenues  2017-12-31  2154655000
# 13                                    us-gaap:Revenues  2016-12-31  2039232000
# 14                                    us-gaap:Revenues  2018-12-31  2382987000
# 15                                    us-gaap:Revenues  2017-12-31  2154655000
# 16                                    us-gaap:Revenues  2016-12-31  2039232000
# 17                                    us-gaap:Revenues  2018-03-31   688002000
# 18                                    us-gaap:Revenues  2018-06-30   578900000
# 19                                    us-gaap:Revenues  2018-09-30   596324000
# 20                                    us-gaap:Revenues  2018-12-31   519761000
# 21                                    us-gaap:Revenues  2017-03-31   418361000
# 22                                    us-gaap:Revenues  2017-06-30   534602000
# 23                                    us-gaap:Revenues  2017-09-30   625732000
# 24                                    us-gaap:Revenues  2017-12-31   575960000
# 25                  us-gaap:CostOfGoodsAndServicesSold  2018-12-31  1962996000
# 26                  us-gaap:CostOfGoodsAndServicesSold  2017-12-31  2070301000
# 27                  us-gaap:CostOfGoodsAndServicesSold  2016-12-31  1867847000
# 28                                 us-gaap:GrossProfit  2018-12-31   419991000
# 29                                 us-gaap:GrossProfit  2017-12-31    84354000
# ..                                                 ...         ...         ...
# 235  us-gaap:IncomeLossFromDiscontinuedOperationsNe...  2016-12-31       -0.47
# 236  us-gaap:IncomeLossFromDiscontinuedOperationsNe...  2018-12-31       -0.30
# 237  us-gaap:IncomeLossFromDiscontinuedOperationsNe...  2017-12-31       -0.33
# 238  us-gaap:IncomeLossFromDiscontinuedOperationsNe...  2016-12-31       -0.47
# 239  us-gaap:IncomeLossFromDiscontinuedOperationsNe...  2018-03-31       -0.09
# 240  us-gaap:IncomeLossFromDiscontinuedOperationsNe...  2018-06-30        0.11
# 241  us-gaap:IncomeLossFromDiscontinuedOperationsNe...  2018-09-30       -0.01
# 242  us-gaap:IncomeLossFromDiscontinuedOperationsNe...  2018-12-31       -0.33
# 243  us-gaap:IncomeLossFromDiscontinuedOperationsNe...  2017-03-31       -0.09
# 244  us-gaap:IncomeLossFromDiscontinuedOperationsNe...  2017-06-30       -0.08
# 245  us-gaap:IncomeLossFromDiscontinuedOperationsNe...  2017-09-30       -0.08
# 246  us-gaap:IncomeLossFromDiscontinuedOperationsNe...  2017-12-31       -0.08
# 247  us-gaap:WeightedAverageNumberOfSharesOutstandi...  2018-12-31    37687552
# 248  us-gaap:WeightedAverageNumberOfSharesOutstandi...  2017-12-31    38731015
# 249  us-gaap:WeightedAverageNumberOfSharesOutstandi...  2016-12-31    40897549
# 250  us-gaap:WeightedAverageNumberOfSharesOutstandi...  2018-12-31    37687552
# 251  us-gaap:WeightedAverageNumberOfSharesOutstandi...  2017-12-31    38731015
# 252  us-gaap:WeightedAverageNumberOfSharesOutstandi...  2016-12-31    40897549
# 253  us-gaap:WeightedAverageNumberOfDilutedSharesOu...  2018-12-31    43653720
# 254  us-gaap:WeightedAverageNumberOfDilutedSharesOu...  2017-12-31    38731015
# 255  us-gaap:WeightedAverageNumberOfDilutedSharesOu...  2016-12-31    40902860
# 256  us-gaap:WeightedAverageNumberOfDilutedSharesOu...  2018-12-31    43653720
# 257  us-gaap:WeightedAverageNumberOfDilutedSharesOu...  2017-12-31    38731015
# 258  us-gaap:WeightedAverageNumberOfDilutedSharesOu...  2016-12-31    40902860
# 259  regi:DiscontinuedOperationWeightedAverageNumbe...  2018-12-31    37687552
# 260  regi:DiscontinuedOperationWeightedAverageNumbe...  2017-12-31    38731015
# 261  regi:DiscontinuedOperationWeightedAverageNumbe...  2016-12-31    40897549
# 262  regi:DiscontinuedOperationWeightedAverageNumbe...  2018-12-31    37687552
# 263  regi:DiscontinuedOperationWeightedAverageNumbe...  2017-12-31    38731015
# 264  regi:DiscontinuedOperationWeightedAverageNumbe...  2016-12-31    40897549
#
# [265 rows x 3 columns]
#                                                account  endInstant       value
# 0                      us-gaap:AlternativeEnergyMember         NaN         NaN
# 1            regi:RenewableIdentificationNumbersMember         NaN         NaN
# 2      regi:AlternativeEnergyGovermentIncentivesMember         NaN         NaN
# 3                 us-gaap:ProductAndServiceOtherMember         NaN         NaN
# 4    us-gaap:RevenueFromContractWithCustomerIncludi...  2019-12-31  2623576000
# 5    us-gaap:RevenueFromContractWithCustomerIncludi...  2018-12-31  2366192000
# 6    us-gaap:RevenueFromContractWithCustomerIncludi...  2017-12-31  2153537000
# 7    us-gaap:RevenueFromContractWithCustomerIncludi...  2019-12-31  2623576000
# 8    us-gaap:RevenueFromContractWithCustomerIncludi...  2018-12-31  2366192000
# 9                                     us-gaap:Revenues  2019-12-31  2625216000
# 10                                    us-gaap:Revenues  2018-12-31  2368478000
# 11                                    us-gaap:Revenues  2017-12-31  2154655000
# 12                                    us-gaap:Revenues  2019-12-31  2625216000
# 13                                    us-gaap:Revenues  2018-12-31  2368478000
# 14                                    us-gaap:Revenues  2019-12-31  2625216000
# 15                                    us-gaap:Revenues  2018-12-31  2368478000
# 16                                    us-gaap:Revenues  2019-12-31  2625216000
# 17                                    us-gaap:Revenues  2018-12-31  2368478000
# 18                                    us-gaap:Revenues  2017-12-31  2154655000
# 19                                    us-gaap:Revenues  2019-12-31  2625216000
# 20                                    us-gaap:Revenues  2018-12-31  2368478000
# 21                                    us-gaap:Revenues  2017-12-31  2154655000
# 22                                    us-gaap:Revenues  2019-03-31   478209000
# 23                                    us-gaap:Revenues  2019-06-30   560643000
# 24                                    us-gaap:Revenues  2019-09-30   584372000
# 25                                    us-gaap:Revenues  2019-12-31  1001992000
# 26                                    us-gaap:Revenues  2018-03-31   673493000
# 27                                    us-gaap:Revenues  2018-06-30   578900000
# 28                                    us-gaap:Revenues  2018-09-30   596324000
# 29                                    us-gaap:Revenues  2018-12-31   519761000
# ..                                                 ...         ...         ...
# 310                    us-gaap:EarningsPerShareDiluted  2018-12-31        6.19
# 311                    us-gaap:EarningsPerShareDiluted  2019-12-31        8.38
# 312                    us-gaap:EarningsPerShareDiluted  2018-12-31        6.19
# 313                    us-gaap:EarningsPerShareDiluted  2017-12-31       -2.04
# 314                    us-gaap:EarningsPerShareDiluted  2019-03-31       -1.17
# 315                    us-gaap:EarningsPerShareDiluted  2019-06-30       -1.65
# 316                    us-gaap:EarningsPerShareDiluted  2019-09-30       -0.42
# 317                    us-gaap:EarningsPerShareDiluted  2019-12-31       11.12
# 318                    us-gaap:EarningsPerShareDiluted  2018-03-31        4.94
# 319                    us-gaap:EarningsPerShareDiluted  2018-06-30        0.78
# 320                    us-gaap:EarningsPerShareDiluted  2018-09-30        0.53
# 321                    us-gaap:EarningsPerShareDiluted  2018-12-31        0.40
# 322  us-gaap:WeightedAverageNumberOfSharesOutstandi...  2019-12-31    38288610
# 323  us-gaap:WeightedAverageNumberOfSharesOutstandi...  2018-12-31    37687552
# 324  us-gaap:WeightedAverageNumberOfSharesOutstandi...  2017-12-31    38731015
# 325  us-gaap:WeightedAverageNumberOfSharesOutstandi...  2019-12-31    38288610
# 326  us-gaap:WeightedAverageNumberOfSharesOutstandi...  2018-12-31    37687552
# 327  us-gaap:WeightedAverageNumberOfSharesOutstandi...  2017-12-31    38731015
# 328  regi:ContinuingOperationWeightedAverageNumbero...  2019-12-31    42320980
# 329  regi:ContinuingOperationWeightedAverageNumbero...  2018-12-31    43653720
# 330  regi:ContinuingOperationWeightedAverageNumbero...  2017-12-31    38731015
# 331  regi:DiscontinuedOperationWeightedAverageNumbe...  2019-12-31    38288610
# 332  regi:DiscontinuedOperationWeightedAverageNumbe...  2018-12-31    37687552
# 333  regi:DiscontinuedOperationWeightedAverageNumbe...  2017-12-31    38731015
# 334  us-gaap:WeightedAverageNumberOfDilutedSharesOu...  2019-12-31    42320980
# 335  us-gaap:WeightedAverageNumberOfDilutedSharesOu...  2018-12-31    43653720
# 336  us-gaap:WeightedAverageNumberOfDilutedSharesOu...  2017-12-31    38731015
# 337  us-gaap:WeightedAverageNumberOfDilutedSharesOu...  2019-12-31    42320980
# 338  us-gaap:WeightedAverageNumberOfDilutedSharesOu...  2018-12-31    43653720
# 339  us-gaap:WeightedAverageNumberOfDilutedSharesOu...  2017-12-31    38731015
#
# [340 rows x 3 columns]
#                                                account  endInstant       value
# 0                      us-gaap:AlternativeEnergyMember         NaN         NaN
# 1      regi:AlternativeEnergyGovermentIncentivesMember         NaN         NaN
# 2                 us-gaap:ProductAndServiceOtherMember         NaN         NaN
# 3    us-gaap:RevenueFromContractWithCustomerIncludi...  2020-12-31  2135741000
# 4    us-gaap:RevenueFromContractWithCustomerIncludi...  2019-12-31  2623576000
# 5    us-gaap:RevenueFromContractWithCustomerIncludi...  2018-12-31  2366192000
# 6                                     us-gaap:Revenues  2020-12-31  2137148000
# 7                                     us-gaap:Revenues  2019-12-31  2625216000
# 8                                     us-gaap:Revenues  2018-12-31  2368478000
# 9                                     us-gaap:Revenues  2020-12-31  2137148000
# 10                                    us-gaap:Revenues  2019-12-31  2625216000
# 11                                    us-gaap:Revenues  2018-12-31  2368478000
# 12                                    us-gaap:Revenues  2020-12-31  2137148000
# 13                                    us-gaap:Revenues  2019-12-31  2625216000
# 14                                    us-gaap:Revenues  2018-12-31  2368478000
# 15                                    us-gaap:Revenues  2020-12-31  2137148000
# 16                                    us-gaap:Revenues  2019-12-31  2625216000
# 17                                    us-gaap:Revenues  2018-12-31  2368478000
# 18                                    us-gaap:Revenues  2020-03-31   472957000
# 19                                    us-gaap:Revenues  2020-06-30   543905000
# 20                                    us-gaap:Revenues  2020-09-30   572358000
# 21                                    us-gaap:Revenues  2020-12-31   547928000
# 22                                    us-gaap:Revenues  2019-03-31   478209000
# 23                                    us-gaap:Revenues  2019-06-30   560643000
# 24                                    us-gaap:Revenues  2019-09-30   584372000
# 25                                    us-gaap:Revenues  2019-12-31  1001992000
# 26                  us-gaap:CostOfGoodsAndServicesSold  2020-12-31  1868794000
# 27                  us-gaap:CostOfGoodsAndServicesSold  2019-12-31  2111324000
# 28                  us-gaap:CostOfGoodsAndServicesSold  2018-12-31  1962996000
# 29                                 us-gaap:GrossProfit  2020-12-31   268354000
# ..                                                 ...         ...         ...
# 267                    us-gaap:EarningsPerShareDiluted  2018-12-31        6.19
# 268                    us-gaap:EarningsPerShareDiluted  2020-12-31        2.76
# 269                    us-gaap:EarningsPerShareDiluted  2019-12-31        8.38
# 270                    us-gaap:EarningsPerShareDiluted  2018-12-31        6.19
# 271                    us-gaap:EarningsPerShareDiluted  2020-03-31        1.67
# 272                    us-gaap:EarningsPerShareDiluted  2020-06-30       -0.04
# 273                    us-gaap:EarningsPerShareDiluted  2020-09-30        0.51
# 274                    us-gaap:EarningsPerShareDiluted  2020-12-31        0.60
# 275                    us-gaap:EarningsPerShareDiluted  2019-03-31       -1.17
# 276                    us-gaap:EarningsPerShareDiluted  2019-06-30       -1.65
# 277                    us-gaap:EarningsPerShareDiluted  2019-09-30       -0.42
# 278                    us-gaap:EarningsPerShareDiluted  2019-12-31       11.12
# 279  us-gaap:WeightedAverageNumberOfSharesOutstandi...  2020-12-31    39199687
# 280  us-gaap:WeightedAverageNumberOfSharesOutstandi...  2019-12-31    38288610
# 281  us-gaap:WeightedAverageNumberOfSharesOutstandi...  2018-12-31    37687552
# 282  us-gaap:WeightedAverageNumberOfSharesOutstandi...  2020-12-31    39199687
# 283  us-gaap:WeightedAverageNumberOfSharesOutstandi...  2019-12-31    38288610
# 284  us-gaap:WeightedAverageNumberOfSharesOutstandi...  2018-12-31    37687552
# 285  regi:ContinuingOperationWeightedAverageNumbero...  2020-12-31    43686989
# 286  regi:ContinuingOperationWeightedAverageNumbero...  2019-12-31    42320980
# 287  regi:ContinuingOperationWeightedAverageNumbero...  2018-12-31    43653720
# 288  regi:DiscontinuedOperationWeightedAverageNumbe...  2020-12-31    43686989
# 289  regi:DiscontinuedOperationWeightedAverageNumbe...  2019-12-31    38288610
# 290  regi:DiscontinuedOperationWeightedAverageNumbe...  2018-12-31    37687552
# 291  us-gaap:WeightedAverageNumberOfDilutedSharesOu...  2020-12-31    43686989
# 292  us-gaap:WeightedAverageNumberOfDilutedSharesOu...  2019-12-31    42320980
# 293  us-gaap:WeightedAverageNumberOfDilutedSharesOu...  2018-12-31    43653720
# 294  us-gaap:WeightedAverageNumberOfDilutedSharesOu...  2020-12-31    43686989
# 295  us-gaap:WeightedAverageNumberOfDilutedSharesOu...  2019-12-31    42320980
# 296  us-gaap:WeightedAverageNumberOfDilutedSharesOu...  2018-12-31    43653720
#
# [297 rows x 3 columns]
#                                                account  endInstant       value
# 0           us-gaap:OtherAlternativeEnergySalesRevenue  2014-12-31   922602000
# 1           us-gaap:OtherAlternativeEnergySalesRevenue  2015-12-31   954742000
# 2           us-gaap:OtherAlternativeEnergySalesRevenue  2016-12-31  1417595000
# 3            regi:RenewableIdentificationNumberRevenue  2014-12-31   130170000
# 4            regi:RenewableIdentificationNumberRevenue  2015-12-31   186539000
# 5            regi:RenewableIdentificationNumberRevenue  2016-12-31   274800000
# 6                   regi:BiodieselGovernmentIncentives  2014-12-31   220634000
# 7                   regi:BiodieselGovernmentIncentives  2015-12-31   245868000
# 8                   regi:BiodieselGovernmentIncentives  2016-12-31   346672000
# 9                             us-gaap:OilAndGasRevenue  2014-12-31  1273406000
# 10                            us-gaap:OilAndGasRevenue  2015-12-31  1387149000
# 11                            us-gaap:OilAndGasRevenue  2016-12-31  2039067000
# 12                   us-gaap:SalesRevenueServicesGross  2014-12-31      425000
# 13                   us-gaap:SalesRevenueServicesGross  2015-12-31      195000
# 14                   us-gaap:SalesRevenueServicesGross  2016-12-31     2165000
# 15                                    us-gaap:Revenues  2014-12-31  1273831000
# 16                                    us-gaap:Revenues  2015-03-31   230918000
# 17                                    us-gaap:Revenues  2015-06-30   373762000
# 18                                    us-gaap:Revenues  2015-09-30   394856000
# 19                                    us-gaap:Revenues  2015-12-31   387808000
# 20                                    us-gaap:Revenues  2015-12-31  1387344000
# 21                                    us-gaap:Revenues  2016-03-31   297870000
# 22                                    us-gaap:Revenues  2016-06-30   558301000
# 23                                    us-gaap:Revenues  2016-09-30   624640000
# 24                                    us-gaap:Revenues  2016-12-31   560421000
# 25                                    us-gaap:Revenues  2016-12-31  2041232000
# 26                             us-gaap:CostOfGoodsSold  2014-12-31   950642000
# 27                             us-gaap:CostOfGoodsSold  2015-12-31  1089437000
# 28                             us-gaap:CostOfGoodsSold  2016-12-31  1616991000
# 29   us-gaap:RelatedPartyTransactionExpensesFromTra...  2014-12-31    42622000
# ..                                                 ...         ...         ...
# 150  us-gaap:NetIncomeLossAvailableToCommonStockhol...  2015-12-31  -151392000
# 151  us-gaap:NetIncomeLossAvailableToCommonStockhol...  2016-12-31    43453000
# 152                      us-gaap:EarningsPerShareBasic  2014-12-31        2.00
# 153                      us-gaap:EarningsPerShareBasic  2015-03-31       -0.86
# 154                      us-gaap:EarningsPerShareBasic  2015-06-30       -0.05
# 155                      us-gaap:EarningsPerShareBasic  2015-09-30       -0.36
# 156                      us-gaap:EarningsPerShareBasic  2015-12-31       -2.18
# 157                      us-gaap:EarningsPerShareBasic  2015-12-31       -3.44
# 158                      us-gaap:EarningsPerShareBasic  2016-03-31       -0.16
# 159                      us-gaap:EarningsPerShareBasic  2016-06-30        0.18
# 160                      us-gaap:EarningsPerShareBasic  2016-09-30        0.59
# 161                      us-gaap:EarningsPerShareBasic  2016-12-31        0.51
# 162                      us-gaap:EarningsPerShareBasic  2016-12-31        1.06
# 163                    us-gaap:EarningsPerShareDiluted  2014-12-31        1.99
# 164                    us-gaap:EarningsPerShareDiluted  2015-03-31       -0.86
# 165                    us-gaap:EarningsPerShareDiluted  2015-06-30       -0.05
# 166                    us-gaap:EarningsPerShareDiluted  2015-09-30       -0.36
# 167                    us-gaap:EarningsPerShareDiluted  2015-12-31       -2.18
# 168                    us-gaap:EarningsPerShareDiluted  2015-12-31       -3.44
# 169                    us-gaap:EarningsPerShareDiluted  2016-03-31       -0.14
# 170                    us-gaap:EarningsPerShareDiluted  2016-06-30        0.18
# 171                    us-gaap:EarningsPerShareDiluted  2016-09-30        0.59
# 172                    us-gaap:EarningsPerShareDiluted  2016-12-31        0.51
# 173                    us-gaap:EarningsPerShareDiluted  2016-12-31        1.06
# 174  us-gaap:WeightedAverageNumberOfSharesOutstandi...  2014-12-31    40740411
# 175  us-gaap:WeightedAverageNumberOfSharesOutstandi...  2015-12-31    43958803
# 176  us-gaap:WeightedAverageNumberOfSharesOutstandi...  2016-12-31    40897549
# 177  us-gaap:WeightedAverageNumberOfDilutedSharesOu...  2014-12-31    40749913
# 178  us-gaap:WeightedAverageNumberOfDilutedSharesOu...  2015-12-31    43958803
# 179  us-gaap:WeightedAverageNumberOfDilutedSharesOu...  2016-12-31    40902860
#
# [180 rows x 3 columns]
#                                                account  endInstant       value
# 0           us-gaap:OtherAlternativeEnergySalesRevenue  2015-12-31   954742000
# 1           us-gaap:OtherAlternativeEnergySalesRevenue  2016-12-31  1417595000
# 2           us-gaap:OtherAlternativeEnergySalesRevenue  2017-12-31  1787308000
# 3            regi:RenewableIdentificationNumberRevenue  2015-12-31   186539000
# 4            regi:RenewableIdentificationNumberRevenue  2016-12-31   274800000
# 5            regi:RenewableIdentificationNumberRevenue  2017-12-31   337501000
# 6                   regi:BiodieselGovernmentIncentives  2015-12-31   245868000
# 7                   regi:BiodieselGovernmentIncentives  2016-12-31   346672000
# 8                   regi:BiodieselGovernmentIncentives  2017-12-31    28728000
# 9                             us-gaap:OilAndGasRevenue  2015-12-31  1387149000
# 10                            us-gaap:OilAndGasRevenue  2016-12-31  2039067000
# 11                            us-gaap:OilAndGasRevenue  2017-12-31  2153537000
# 12                   us-gaap:SalesRevenueServicesGross  2015-12-31      195000
# 13                   us-gaap:SalesRevenueServicesGross  2016-12-31     2165000
# 14                   us-gaap:SalesRevenueServicesGross  2017-12-31     4706000
# 15                                    us-gaap:Revenues  2015-12-31  1387344000
# 16                                    us-gaap:Revenues  2016-03-31   297870000
# 17                                    us-gaap:Revenues  2016-06-30   558301000
# 18                                    us-gaap:Revenues  2016-09-30   624640000
# 19                                    us-gaap:Revenues  2016-12-31   560421000
# 20                                    us-gaap:Revenues  2016-12-31  2041232000
# 21                                    us-gaap:Revenues  2017-03-31   418893000
# 22                                    us-gaap:Revenues  2017-06-30   535103000
# 23                                    us-gaap:Revenues  2017-09-30   626983000
# 24                                    us-gaap:Revenues  2017-12-31   577264000
# 25                                    us-gaap:Revenues  2017-12-31  2158243000
# 26                             us-gaap:CostOfGoodsSold  2015-12-31  1093979000
# 27                             us-gaap:CostOfGoodsSold  2016-12-31  1616991000
# 28                             us-gaap:CostOfGoodsSold  2017-12-31  1805410000
# 29           regi:CostofRenewableIdentificationNumbers  2015-12-31   182688000
# ..                                                 ...         ...         ...
# 147                      us-gaap:EarningsPerShareBasic  2016-12-31        0.51
# 148                      us-gaap:EarningsPerShareBasic  2016-12-31        1.06
# 149                      us-gaap:EarningsPerShareBasic  2017-03-31       -0.41
# 150                      us-gaap:EarningsPerShareBasic  2017-06-30       -0.90
# 151                      us-gaap:EarningsPerShareBasic  2017-09-30       -0.29
# 152                      us-gaap:EarningsPerShareBasic  2017-12-31       -0.44
# 153                      us-gaap:EarningsPerShareBasic  2017-12-31       -2.04
# 154                    us-gaap:EarningsPerShareDiluted  2015-12-31       -3.44
# 155                    us-gaap:EarningsPerShareDiluted  2016-03-31       -0.14
# 156                    us-gaap:EarningsPerShareDiluted  2016-06-30        0.18
# 157                    us-gaap:EarningsPerShareDiluted  2016-09-30        0.59
# 158                    us-gaap:EarningsPerShareDiluted  2016-12-31        0.51
# 159                    us-gaap:EarningsPerShareDiluted  2016-12-31        1.06
# 160                    us-gaap:EarningsPerShareDiluted  2017-03-31       -0.41
# 161                    us-gaap:EarningsPerShareDiluted  2017-06-30       -0.90
# 162                    us-gaap:EarningsPerShareDiluted  2017-09-30       -0.29
# 163                    us-gaap:EarningsPerShareDiluted  2017-12-31       -0.44
# 164                    us-gaap:EarningsPerShareDiluted  2017-12-31       -2.04
# 165  us-gaap:WeightedAverageNumberOfSharesOutstandi...  2015-12-31    43958803
# 166  us-gaap:WeightedAverageNumberOfSharesOutstandi...  2015-12-31    43958803
# 167  us-gaap:WeightedAverageNumberOfSharesOutstandi...  2016-12-31    40897549
# 168  us-gaap:WeightedAverageNumberOfSharesOutstandi...  2016-12-31    40897549
# 169  us-gaap:WeightedAverageNumberOfSharesOutstandi...  2017-12-31    38731015
# 170  us-gaap:WeightedAverageNumberOfSharesOutstandi...  2017-12-31    38731015
# 171  us-gaap:WeightedAverageNumberOfDilutedSharesOu...  2015-12-31    43958803
# 172  us-gaap:WeightedAverageNumberOfDilutedSharesOu...  2015-12-31    43958803
# 173  us-gaap:WeightedAverageNumberOfDilutedSharesOu...  2016-12-31    40902860
# 174  us-gaap:WeightedAverageNumberOfDilutedSharesOu...  2016-12-31    40902860
# 175  us-gaap:WeightedAverageNumberOfDilutedSharesOu...  2017-12-31    38731015
# 176  us-gaap:WeightedAverageNumberOfDilutedSharesOu...  2017-12-31    38731015
#
# [177 rows x 3 columns]
#                                                account  endInstant       value
# 0                      us-gaap:AlternativeEnergyMember         NaN         NaN
# 1            regi:RenewableIdentificationNumbersMember         NaN         NaN
# 2      regi:AlternativeEnergyGovermentIncentivesMember         NaN         NaN
# 3                 us-gaap:ProductAndServiceOtherMember         NaN         NaN
# 4    us-gaap:RevenueFromContractWithCustomerIncludi...  2019-12-31  2639753000
# 5    us-gaap:RevenueFromContractWithCustomerIncludi...  2018-12-31  2380701000
# 6    us-gaap:RevenueFromContractWithCustomerIncludi...  2017-12-31  2153537000
# 7                                     us-gaap:Revenues  2019-12-31  2641393000
# 8                                     us-gaap:Revenues  2018-12-31  2382987000
# 9                                     us-gaap:Revenues  2017-12-31  2154655000
# 10                                    us-gaap:Revenues  2019-12-31  2641393000
# 11                                    us-gaap:Revenues  2018-12-31  2382987000
# 12                                    us-gaap:Revenues  2019-12-31  2641393000
# 13                                    us-gaap:Revenues  2018-12-31  2382987000
# 14                                    us-gaap:Revenues  2017-12-31  2154655000
# 15                                    us-gaap:Revenues  2019-12-31  2641393000
# 16                                    us-gaap:Revenues  2018-12-31  2382987000
# 17                                    us-gaap:Revenues  2017-12-31  2154655000
# 18                                    us-gaap:Revenues  2019-03-31   478209000
# 19                                    us-gaap:Revenues  2019-06-30   560643000
# 20                                    us-gaap:Revenues  2019-09-30   584372000
# 21                                    us-gaap:Revenues  2019-12-31  1018169000
# 22                                    us-gaap:Revenues  2018-03-31   688002000
# 23                                    us-gaap:Revenues  2018-06-30   578900000
# 24                                    us-gaap:Revenues  2018-09-30   596324000
# 25                                    us-gaap:Revenues  2018-12-31   519761000
# 26                  us-gaap:CostOfGoodsAndServicesSold  2019-12-31  2111324000
# 27                  us-gaap:CostOfGoodsAndServicesSold  2018-12-31  1962996000
# 28                  us-gaap:CostOfGoodsAndServicesSold  2017-12-31  2070301000
# 29                                 us-gaap:GrossProfit  2019-12-31   530069000
# ..                                                 ...         ...         ...
# 276                    us-gaap:EarningsPerShareDiluted  2017-12-31       -2.04
# 277                    us-gaap:EarningsPerShareDiluted  2019-12-31        8.78
# 278                    us-gaap:EarningsPerShareDiluted  2018-12-31        6.52
# 279                    us-gaap:EarningsPerShareDiluted  2017-12-31       -2.04
# 280                    us-gaap:EarningsPerShareDiluted  2019-03-31       -1.16
# 281                    us-gaap:EarningsPerShareDiluted  2019-06-30       -1.64
# 282                    us-gaap:EarningsPerShareDiluted  2019-09-30       -0.41
# 283                    us-gaap:EarningsPerShareDiluted  2019-12-31       11.50
# 284                    us-gaap:EarningsPerShareDiluted  2018-03-31        5.30
# 285                    us-gaap:EarningsPerShareDiluted  2018-06-30        0.78
# 286                    us-gaap:EarningsPerShareDiluted  2018-09-30        0.53
# 287                    us-gaap:EarningsPerShareDiluted  2018-12-31        0.40
# 288  us-gaap:WeightedAverageNumberOfSharesOutstandi...  2019-12-31    38288610
# 289  us-gaap:WeightedAverageNumberOfSharesOutstandi...  2018-12-31    37687552
# 290  us-gaap:WeightedAverageNumberOfSharesOutstandi...  2017-12-31    38731015
# 291  us-gaap:WeightedAverageNumberOfSharesOutstandi...  2019-12-31    38288610
# 292  us-gaap:WeightedAverageNumberOfSharesOutstandi...  2018-12-31    37687552
# 293  us-gaap:WeightedAverageNumberOfSharesOutstandi...  2017-12-31    38731015
# 294  regi:ContinuingOperationWeightedAverageNumbero...  2019-12-31    42320980
# 295  regi:ContinuingOperationWeightedAverageNumbero...  2018-12-31    43653720
# 296  regi:ContinuingOperationWeightedAverageNumbero...  2017-12-31    38731015
# 297  regi:DiscontinuedOperationWeightedAverageNumbe...  2019-12-31    38288610
# 298  regi:DiscontinuedOperationWeightedAverageNumbe...  2018-12-31    37687552
# 299  regi:DiscontinuedOperationWeightedAverageNumbe...  2017-12-31    38731015
# 300  us-gaap:WeightedAverageNumberOfDilutedSharesOu...  2019-12-31    42320980
# 301  us-gaap:WeightedAverageNumberOfDilutedSharesOu...  2018-12-31    43653720
# 302  us-gaap:WeightedAverageNumberOfDilutedSharesOu...  2017-12-31    38731015
# 303  us-gaap:WeightedAverageNumberOfDilutedSharesOu...  2019-12-31    42320980
# 304  us-gaap:WeightedAverageNumberOfDilutedSharesOu...  2018-12-31    43653720
# 305  us-gaap:WeightedAverageNumberOfDilutedSharesOu...  2017-12-31    38731015
#
# [306 rows x 3 columns]
